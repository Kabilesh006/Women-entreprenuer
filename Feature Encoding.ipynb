# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# LOAD CLEANED DATASET

# %%
df = pd.read_csv("startup_cleaned_dataset.csv")
print("Dataset Shape:",df.shape)
df.head()
df.info()
# Out:
# Dataset Shape: (923, 42)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state_code                923 non-null    object
#  1   latitude                  923 non-null    float64
#  2   longitude                 923 non-null    float64
#  3   zip_code                  923 non-null    object
#  4   city                      923 non-null    object
#  5   labels                    923 non-null    int64
#  6   founded_at                923 non-null    object
#  7   first_funding_at          923 non-null    object
#  8   last_funding_at           923 non-null    object
#  9   age_first_funding_year    923 non-null    float64
#  10  age_last_funding_year     923 non-null    float64
#  11  age_first_milestone_year  923 non-null    float64
#  12  age_last_milestone_year   923 non-null    float64
#  13  relationships             923 non-null    int64
#  14  funding_rounds            923 non-null    int64
#  15  funding_total_usd         923 non-null    int64
#  16  milestones                923 non-null    int64
#  17  is_CA                     923 non-null    int64
#  18  is_NY                     923 non-null    int64
#  19  is_MA                     923 non-null    int64
#  20  is_TX                     923 non-null    int64
#  21  is_otherstate             923 non-null    int64
#  22  category_code             923 non-null    object
#  23  is_software               923 non-null    int64
#  24  is_web                    923 non-null    int64
#  25  is_mobile                 923 non-null    int64
#  26  is_enterprise             923 non-null    int64
#  27  is_advertising            923 non-null    int64
#  28  is_gamesvideo             923 non-null    int64
#  29  is_ecommerce              923 non-null    int64
#  30  is_biotech                923 non-null    int64
#  31  is_consulting             923 non-null    int64
#  32  is_othercategory          923 non-null    int64
#  33  has_VC                    923 non-null    int64
#  34  has_angel                 923 non-null    int64
#  35  has_roundA                923 non-null    int64
#  36  has_roundB                923 non-null    int64
#  37  has_roundC                923 non-null    int64
#  38  has_roundD                923 non-null    int64
#  39  avg_participants          923 non-null    float64
#  40  is_top500                 923 non-null    int64
#  41  status                    923 non-null    object
# dtypes: float64(7), int64(27), object(8)
# memory usage: 303.0+ KB

# %% [markdown]
# CHECK REMAINING COLUMNS

# %%
print(df.columns.tolist())
# Out:
# ['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels', 'founded_at', 'first_funding_at', 'last_funding_at', 'age_first_funding_year', 'age_last_funding_year', 'age_first_milestone_year', 'age_last_milestone_year', 'relationships', 'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software', 'is_web', 'is_mobile', 'is_enterprise', 'is_advertising', 'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting', 'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB', 'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status']

# %% [markdown]
# CONVERT TARGET VARIABLE

# %%
df["status"]=df["status"].map({"acquired":1,"closed":0})
df["status"].value_counts()
# Out:
# status
# 1    597
# 0    326
# Name: count, dtype: int64

# %% [markdown]
# CHECK CATERGORICAL COLUMNS

# %%
categorical_cols=df.select_dtypes(include="string").columns.tolist()
print("Categorical Columns:")
print(categorical_cols)
# Out:
# Categorical Columns:
# []

# %%
df.drop(columns=['zip_code','city','founded_at','first_funding_at','last_funding_at'],inplace=True)

# %% [markdown]
# ONE HOT ENCODING

# %%
df_encoded=pd.get_dummies(
    df,
    columns=['state_code', 'category_code'],
    drop_first=True
)
print(df_encoded.shape)
# Out:
# (923, 103)

# %%
X = df_encoded[[
    "funding_total_usd", "funding_rounds", "milestones", 
    "relationships", "avg_participants", "is_top500",
    "age_first_funding_year", "age_last_funding_year",
    "age_first_milestone_year", "age_last_milestone_year",
    "has_VC", "has_angel", "has_roundA", "has_roundB", 
    "has_roundC", "has_roundD",
    "is_software", "is_web", "is_mobile", "is_enterprise",
    "is_biotech", "is_CA", "is_NY", "is_MA", "is_TX"
]]
y = df_encoded["status"]

# %%
df["status"] = df["status"].map({"acquired": 1, "closed": 0})

df.to_csv("startup_final.csv", index=False)

print(df["status"].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
